# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import StackingRegressor
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.compose import ColumnTransformer
import statsmodels.api as sma
from sklearn.model_selection import cross_val_score,GridSearchCV,RandomizedSearchCV
from sklearn import tree
from scipy.stats import randint
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.decomposition import PCA

# %%
df1=pd.read_csv("df_trim.csv")
df1.head()
# Out:
#    product_id  time_id  customer_id  promotion_id  store_id  store_sales  \
# 0         451      677         7366           207         3         7.12
# 1        1293      677         7366           207         3         5.76
# 2         738      677         7366           207         3         5.55
# 3        1426      677         8947           207         3         7.48
# 4         338      677         8947           207         3         2.28
#
#    store_cost  unit_sales  product_class_id    brand_name  ... houseowner  \
# 0      2.2784           4                55      Red Wing  ...          Y
# 1      1.7856           4                14        Booker  ...          Y
# 2      2.0535           3                39  Consolidated  ...          Y
# 3      2.2440           2                61      Hermanos  ...          Y
# 4      1.0488           4                58        Better  ...          Y
#
#    num_cars_owned     fullname   the_date  the_day  the_year  the_month  \
# 0               4    Ann Smith  11/7/1997   Friday      1997         11
# 1               4    Ann Smith  11/7/1997   Friday      1997         11
# 2               4    Ann Smith  11/7/1997   Friday      1997         11
# 3               2  Robert Bell  11/7/1997   Friday      1997         11
# 4               2  Robert Bell  11/7/1997   Friday      1997         11
#
#    day_of_month  day_since_epoch  promotion_period
# 0             7            34279                 4
# 1             7            34279                 4
# 2             7            34279                 4
# 3             7            34279                 4
# 4             7            34279                 4
#
# [5 rows x 94 columns]

# %%
#Impute null values with median for specified columns
columns_to_impute = ['store_sqft', 'grocery_sqft', 'frozen_sqft', 'meat_sqft']
imputer = SimpleImputer(strategy='median')
df1[columns_to_impute] = imputer.fit_transform(df1[columns_to_impute])

# %%
# Check for remaining null values
df_null = df1.isnull().sum()
df_null
# Out:
# product_id          0
# time_id             0
# customer_id         0
# promotion_id        0
# store_id            0
#                    ..
# the_year            0
# the_month           0
# day_of_month        0
# day_since_epoch     0
# promotion_period    0
# Length: 94, dtype: int64

# %%
# Remove specified columns
columns_to_remove = ["lname", "fname", "mi", "address1", "address2"]
df1 = df1.drop(columns=columns_to_remove)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70751 entries, 0 to 70750
# Data columns (total 89 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   product_id             70751 non-null  int64
#  1   time_id                70751 non-null  int64
#  2   customer_id            70751 non-null  int64
#  3   promotion_id           70751 non-null  int64
#  4   store_id               70751 non-null  int64
#  5   store_sales            70751 non-null  float64
#  6   store_cost             70751 non-null  float64
#  7   unit_sales             70751 non-null  int64
#  8   product_class_id       70751 non-null  int64
#  9   brand_name             70751 non-null  object
#  10  product_name           70751 non-null  object
#  11  SKU                    70751 non-null  int64
#  12  SRP                    70751 non-null  float64
#  13  gross_weight           70751 non-null  float64
#  14  net_weight             70751 non-null  float64
#  15  recyclable_package     70751 non-null  int64
#  16  low_fat                70751 non-null  int64
#  17  units_per_case         70751 non-null  int64
#  18  cases_per_pallet       70751 non-null  int64
#  19  shelf_width            70751 non-null  float64
#  20  shelf_height           70751 non-null  float64
#  21  shelf_depth            70751 non-null  float64
#  22  subcategory            70751 non-null  object
#  23  category               70751 non-null  object
#  24  department             70751 non-null  object
#  25  family                 70751 non-null  object
#  26  promotion_district_id  70751 non-null  int64
#  27  promotion_name         70751 non-null  object
#  28  media_type             70751 non-null  object
#  29  cost                   70751 non-null  int64
#  30  start_date             70751 non-null  object
#  31  end_date               70751 non-null  object
#  32  region_id              70751 non-null  int64
#  33  sales_city             70751 non-null  object
#  34  sales_state_province   70751 non-null  object
#  35  sales_district         70751 non-null  object
#  36  sales_region           70751 non-null  object
#  37  sales_country          70751 non-null  object
#  38  sales_district_id      70751 non-null  int64
#  39  store_type             70751 non-null  object
#  40  store_name             70751 non-null  object
#  41  store_number           70751 non-null  int64
#  42  store_street_address   70751 non-null  object
#  43  store_city             70751 non-null  object
#  44  store_state            70751 non-null  object
#  45  store_postal_code      70751 non-null  int64
#  46  store_country          70751 non-null  object
#  47  store_manager          70751 non-null  object
#  48  store_phone            70751 non-null  object
#  49  store_fax              70751 non-null  object
#  50  first_opened_date      70751 non-null  object
#  51  last_remodel_date      70751 non-null  object
#  52  store_sqft             70751 non-null  float64
#  53  grocery_sqft           70751 non-null  float64
#  54  frozen_sqft            70751 non-null  float64
#  55  meat_sqft              70751 non-null  float64
#  56  coffee_bar             70751 non-null  int64
#  57  video_store            70751 non-null  int64
#  58  salad_bar              70751 non-null  int64
#  59  prepared_food          70751 non-null  int64
#  60  florist                70751 non-null  int64
#  61  account_num            70751 non-null  int64
#  62  city                   70751 non-null  object
#  63  state_province         70751 non-null  object
#  64  postal_code            70751 non-null  int64
#  65  country                70751 non-null  object
#  66  customer_region_id     70751 non-null  int64
#  67  phone1                 70751 non-null  object
#  68  phone2                 70751 non-null  object
#  69  birthdate              70751 non-null  object
#  70  marital_status         70751 non-null  object
#  71  yearly_income          70751 non-null  object
#  72  gender                 70751 non-null  object
#  73  total_children         70751 non-null  int64
#  74  num_children_at_home   70751 non-null  int64
#  75  education              70751 non-null  object
#  76  date_accnt_opened      70751 non-null  object
#  77  member_card            70751 non-null  object
#  78  occupation             70751 non-null  object
#  79  houseowner             70751 non-null  object
#  80  num_cars_owned         70751 non-null  int64
#  81  fullname               70751 non-null  object
#  82  the_date               70751 non-null  object
#  83  the_day                70751 non-null  object
#  84  the_year               70751 non-null  int64
#  85  the_month              70751 non-null  int64
#  86  day_of_month           70751 non-null  int64
#  87  day_since_epoch        70751 non-null  int64
#  88  promotion_period       70751 non-null  int64
# dtypes: float64(12), int64(34), object(43)
# memory usage: 48.0+ MB

# %% [markdown]
# # PCA for numerical columns

# %% [markdown]
# # numerical columns

# %%
df_num=df1[['store_sales', 'store_cost', 'unit_sales','SRP', 'gross_weight',
       'net_weight', 'units_per_case',
       'cases_per_pallet', 'shelf_width', 'shelf_height', 'shelf_depth',
       'cost','store_sqft','grocery_sqft', 'frozen_sqft', 'meat_sqft', 
       'total_children', 'num_children_at_home', 'num_cars_owned','day_since_epoch', 'promotion_period']]

# %%
df_num.shape
# Out:
# (70751, 21)

# %%
df_num.corr()
# Out:
#                       store_sales  store_cost  unit_sales       SRP  \
# store_sales              1.000000    0.954721    0.506463  0.831683
# store_cost               0.954721    1.000000    0.483684  0.793690
# unit_sales               0.506463    0.483684    1.000000 -0.001458
# SRP                      0.831683    0.793690   -0.001458  1.000000
# gross_weight             0.035323    0.034339    0.002653  0.042143
# net_weight               0.030964    0.030173    0.001956  0.037472
# units_per_case          -0.006682   -0.006083    0.002895 -0.009469
# cases_per_pallet         0.020763    0.019050   -0.005181  0.028148
# shelf_width             -0.007104   -0.007882   -0.004848 -0.003762
# shelf_height            -0.002970   -0.004228    0.004326 -0.006952
# shelf_depth             -0.012358   -0.010534   -0.004210 -0.013395
# cost                    -0.002130   -0.001552   -0.010038  0.002819
# store_sqft               0.014345    0.016543    0.029064  0.001447
# grocery_sqft             0.009673    0.012013    0.023259 -0.000662
# frozen_sqft              0.016534    0.017911    0.028641  0.003761
# meat_sqft                0.016531    0.017907    0.028635  0.003761
# total_children           0.079918    0.075720    0.160142 -0.002013
# num_children_at_home     0.028998    0.024283    0.063025 -0.002002
# num_cars_owned           0.004698    0.003620    0.018828 -0.005722
# day_since_epoch          0.004083    0.006454    0.012703 -0.002604
# promotion_period        -0.007396   -0.005551    0.001676 -0.008061
#
#                       gross_weight  net_weight  units_per_case  \
# store_sales               0.035323    0.030964       -0.006682
# store_cost                0.034339    0.030173       -0.006083
# unit_sales                0.002653    0.001956        0.002895
# SRP                       0.042143    0.037472       -0.009469
# gross_weight              1.000000    0.988892       -0.012524
# net_weight                0.988892    1.000000       -0.015189
# units_per_case           -0.012524   -0.015189        1.000000
# cases_per_pallet         -0.009303   -0.010974       -0.017440
# shelf_width              -0.009721   -0.010019        0.002274
# shelf_height             -0.018058   -0.017077        0.022014
# shelf_depth              -0.006542   -0.003119        0.037483
# cost                      0.000151    0.000164       -0.002231
# store_sqft               -0.004841   -0.004028        0.001836
# grocery_sqft             -0.004352   -0.003406        0.003488
# frozen_sqft              -0.003824   -0.003502       -0.001150
# meat_sqft                -0.003824   -0.003502       -0.001150
# total_children            0.000464    0.000498        0.002606
# num_children_at_home     -0.003467   -0.003591        0.002079
# num_cars_owned            0.005372    0.004886       -0.008283
# day_since_epoch          -0.000495   -0.000092       -0.004951
# promotion_period          0.000158    0.000469        0.007424
#
#                       cases_per_pallet  shelf_width  shelf_height  ...  \
# store_sales                   0.020763    -0.007104     -0.002970  ...
# store_cost                    0.019050    -0.007882     -0.004228  ...
# unit_sales                   -0.005181    -0.004848      0.004326  ...
# SRP                           0.028148    -0.003762     -0.006952  ...
# gross_weight                 -0.009303    -0.009721     -0.018058  ...
# net_weight                   -0.010974    -0.010019     -0.017077  ...
# units_per_case               -0.017440     0.002274      0.022014  ...
# cases_per_pallet              1.000000     0.025709     -0.339911  ...
# shelf_width                   0.025709     1.000000      0.009367  ...
# shelf_height                 -0.339911     0.009367      1.000000  ...
# shelf_depth                   0.027523    -0.023652     -0.001535  ...
# cost                         -0.000974    -0.006242     -0.002234  ...
# store_sqft                    0.002915     0.005919     -0.000075  ...
# grocery_sqft                  0.003496     0.005414      0.000646  ...
# frozen_sqft                   0.000972     0.004807     -0.001491  ...
# meat_sqft                     0.000971     0.004806     -0.001490  ...
# total_children               -0.004819     0.005278      0.002672  ...
# num_children_at_home         -0.001166     0.003106      0.004461  ...
# num_cars_owned               -0.005075     0.004362      0.004213  ...
# day_since_epoch               0.002207     0.001629      0.001404  ...
# promotion_period             -0.001522    -0.001965      0.001287  ...
#
#                           cost  store_sqft  grocery_sqft  frozen_sqft  \
# store_sales          -0.002130    0.014345      0.009673     0.016534
# store_cost           -0.001552    0.016543      0.012013     0.017911
# unit_sales           -0.010038    0.029064      0.023259     0.028641
# SRP                   0.002819    0.001447     -0.000662     0.003761
# gross_weight          0.000151   -0.004841     -0.004352    -0.003824
# net_weight            0.000164   -0.004028     -0.003406    -0.003502
# units_per_case       -0.002231    0.001836      0.003488    -0.001150
# cases_per_pallet     -0.000974    0.002915      0.003496     0.000972
# shelf_width          -0.006242    0.005919      0.005414     0.004807
# shelf_height         -0.002234   -0.000075      0.000646    -0.001491
# shelf_depth          -0.001511    0.001132      0.002045    -0.001151
# cost                  1.000000   -0.037454     -0.024402    -0.046049
# store_sqft           -0.037454    1.000000      0.912663     0.784332
# grocery_sqft         -0.024402    0.912663      1.000000     0.464685
# frozen_sqft          -0.046049    0.784332      0.464685     1.000000
# meat_sqft            -0.046038    0.784370      0.464731     1.000000
# total_children       -0.007294    0.000229      0.016438    -0.025662
# num_children_at_home -0.007267    0.005758      0.023265    -0.022498
# num_cars_owned        0.017099   -0.014855     -0.016838    -0.007535
# day_since_epoch      -0.042454    0.057931      0.107703    -0.033757
# promotion_period     -0.115070   -0.015353     -0.024193     0.009633
#
#                       meat_sqft  total_children  num_children_at_home  \
# store_sales            0.016531        0.079918              0.028998
# store_cost             0.017907        0.075720              0.024283
# unit_sales             0.028635        0.160142              0.063025
# SRP                    0.003761       -0.002013             -0.002002
# gross_weight          -0.003824        0.000464             -0.003467
# net_weight            -0.003502        0.000498             -0.003591
# units_per_case        -0.001150        0.002606              0.002079
# cases_per_pallet       0.000971       -0.004819             -0.001166
# shelf_width            0.004806        0.005278              0.003106
# shelf_height          -0.001490        0.002672              0.004461
# shelf_depth           -0.001150        0.007317              0.005725
# cost                  -0.046038       -0.007294             -0.007267
# store_sqft             0.784370        0.000229              0.005758
# grocery_sqft           0.464731        0.016438              0.023265
# frozen_sqft            1.000000       -0.025662             -0.022498
# meat_sqft              1.000000       -0.025657             -0.022491
# total_children        -0.025657        1.000000              0.390706
# num_children_at_home  -0.022491        0.390706              1.000000
# num_cars_owned        -0.007530        0.093485              0.116569
# day_since_epoch       -0.033726        0.012886              0.012020
# promotion_period       0.009632       -0.005128             -0.010215
#
#                       num_cars_owned  day_since_epoch  promotion_period
# store_sales                 0.004698         0.004083         -0.007396
# store_cost                  0.003620         0.006454         -0.005551
# unit_sales                  0.018828         0.012703          0.001676
# SRP                        -0.005722        -0.002604         -0.008061
# gross_weight                0.005372        -0.000495          0.000158
# net_weight                  0.004886        -0.000092          0.000469
# units_per_case             -0.008283        -0.004951          0.007424
# cases_per_pallet           -0.005075         0.002207         -0.001522
# shelf_width                 0.004362         0.001629         -0.001965
# shelf_height                0.004213         0.001404          0.001287
# shelf_depth                 0.002732        -0.001388         -0.002117
# cost                        0.017099        -0.042454         -0.115070
# store_sqft                 -0.014855         0.057931         -0.015353
# grocery_sqft               -0.016838         0.107703         -0.024193
# frozen_sqft                -0.007535        -0.033757          0.009633
# meat_sqft                  -0.007530        -0.033726          0.009632
# total_children              0.093485         0.012886         -0.005128
# num_children_at_home        0.116569         0.012020         -0.010215
# num_cars_owned              1.000000        -0.000656         -0.006101
# day_since_epoch            -0.000656         1.000000         -0.232424
# promotion_period           -0.006101        -0.232424          1.000000
#
# [21 rows x 21 columns]

# %%
X=df_num.drop("cost",axis=1)
y=df_num["cost"]

# %%
ss=StandardScaler()
X_s=pd.DataFrame(data=ss.fit_transform(X),columns=X.columns)

# %%
pca=PCA()
X_pca=pd.DataFrame(data=pca.fit_transform(X_s),columns=[f"PC{i}" for i in range (1,21)])

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=42)

# %%
pca.explained_variance_ratio_
# Out:
# array([1.61709892e-01, 1.45905938e-01, 9.91976433e-02, 7.38259999e-02,
#        6.71085635e-02, 6.26504748e-02, 5.22057359e-02, 5.01458855e-02,
#        4.94692439e-02, 4.75731717e-02, 4.67104604e-02, 4.09709374e-02,
#        3.45611477e-02, 3.28047252e-02, 2.98746345e-02, 3.62297576e-03,
#        1.06058455e-03, 5.54223339e-04, 4.77602681e-05, 2.76531593e-09])

# %%
df_var_pca=pd.DataFrame({"component":range(1,21),"Variance":np.cumsum(pca.explained_variance_ratio_)})

# %%
df_var_pca
# Out:
#     component  Variance
# 0           1  0.161710
# 1           2  0.307616
# 2           3  0.406813
# 3           4  0.480639
# 4           5  0.547748
# 5           6  0.610399
# 6           7  0.662604
# 7           8  0.712750
# 8           9  0.762219
# 9          10  0.809793
# 10         11  0.856503
# 11         12  0.897474
# 12         13  0.932035
# 13         14  0.964840
# 14         15  0.994714
# 15         16  0.998337
# 16         17  0.999398
# 17         18  0.999952
# 18         19  1.000000
# 19         20  1.000000

# %% [markdown]
# # Linear Regression

# %%
model_lr=LinearRegression().fit(X_train,y_train)

# %%
ypred_train=model_lr.predict(X_train)
ypred_test=model_lr.predict(X_test)

# %%
mse_train=mean_squared_error(y_train,ypred_train)
mse_test=mean_squared_error(y_test,ypred_test)
print("Mean squared error for train data:",mse_train)
print("Mean squared error for test data:",mse_test)
# Out:
# Mean squared error for train data: 8627373.272357
# Mean squared error for test data: 8634543.143823057

# %%
from sklearn.model_selection import cross_val_score
model_lr=LinearRegression()
# Example: Cross-validation with 3 folds
scores = cross_val_score(model_lr, X_pca, y, cv=3, scoring='neg_mean_squared_error')
print("Cross-validated RMSE:", -scores)
# Out:
# Cross-validated RMSE: [8600910.33393185 9357799.82287908 8572833.87563128]

# %%
print(np.min(-scores),np.max(-scores),np.mean(-scores))
# Out:
# 8572833.875631278 9357799.82287908 8843848.01081407

# %% [markdown]
# # Decision Tree Regressor

# %%
dtr=DecisionTreeRegressor(random_state=42)
model_dtr=dtr.fit(X_train,y_train)

# %%
df_imp_dt=pd.DataFrame({"feature":X_train.columns,"importance":model_dtr.feature_importances_})
df_imp_dt.sort_values(by="importance",ascending=False)
# Out:
#    feature  importance
# 12    PC13    0.226457
# 5      PC6    0.157876
# 19    PC20    0.140619
# 11    PC12    0.138914
# 18    PC19    0.061906
# 10    PC11    0.052147
# 0      PC1    0.043317
# 3      PC4    0.038115
# 8      PC9    0.024787
# 14    PC15    0.020999
# 4      PC5    0.011906
# 16    PC17    0.011093
# 6      PC7    0.009992
# 1      PC2    0.009808
# 13    PC14    0.009345
# 7      PC8    0.009208
# 17    PC18    0.009146
# 9     PC10    0.008616
# 15    PC16    0.008047
# 2      PC3    0.007700

# %%
ypred_train=model_dtr.predict(X_train)
ypred_test=model_dtr.predict(X_test)

# %%
mse_train=mean_squared_error(y_train,ypred_train)
mse_test=mean_squared_error(y_test,ypred_test)
print("Mean squared error for train data:",mse_train)
print("Mean squared error for test data:",mse_test)
# Out:
# Mean squared error for train data: 0.0
# Mean squared error for test data: 5332801.537983181

# %%
# Example: Cross-validation with 3 folds
scores = cross_val_score(DecisionTreeRegressor(random_state=42), X_pca, y, cv=3, scoring='neg_mean_squared_error')
print("Cross-validated MSE:", -scores)
# Out:
# Cross-validated MSE: [14479850.99092605 15015151.64251187 14847995.61959886]

# %%
print(np.min(-scores),np.max(-scores),np.mean(-scores))
# Out:
# 14479850.990926052 15015151.642511873 14780999.41767893

# %% [markdown]
# # Random Forest Regressor

# %%
rfr=RandomForestRegressor(random_state=42,n_jobs=-1)
model_rfr=rfr.fit(X_train,y_train)

# %%
df_imp_rfr=pd.DataFrame({"feature":X_train.columns,"importance":model_rfr.feature_importances_})
df_imp_rfr.sort_values(by="importance",ascending=False)
# Out:
#    feature  importance
# 12    PC13    0.198787
# 5      PC6    0.157791
# 19    PC20    0.147963
# 11    PC12    0.142847
# 18    PC19    0.070057
# 10    PC11    0.047159
# 0      PC1    0.039656
# 3      PC4    0.037243
# 8      PC9    0.024376
# 14    PC15    0.022074
# 4      PC5    0.015173
# 16    PC17    0.012046
# 6      PC7    0.011679
# 7      PC8    0.011128
# 9     PC10    0.011048
# 13    PC14    0.010721
# 2      PC3    0.010668
# 15    PC16    0.010219
# 17    PC18    0.010022
# 1      PC2    0.009343

# %%
ypred_train=model_rfr.predict(X_train)
ypred_test=model_rfr.predict(X_test)

# %%
mse_train=mean_squared_error(y_train,ypred_train)
mse_test=mean_squared_error(y_test,ypred_test)
print("Mean squared error for train data:",mse_train)
print("Mean squared error for test data:",mse_test)
# Out:
# Mean squared error for train data: 338642.76370522444
# Mean squared error for test data: 2403670.2247216664

# %%
# Example: Cross-validation with 3 folds
scores = cross_val_score(RandomForestRegressor(random_state=42,n_jobs=-1), X, y, cv=3, scoring='neg_mean_squared_error')
print("Cross-validated RMSE:", -scores)
# Out:
# Cross-validated RMSE: [12356471.58222615 10615149.74954203  8684129.45815665]

# %%
print(np.min(-scores),np.max(-scores),np.mean(-scores))
# Out:
# 8684129.45815665 12356471.582226152 10551916.929974945

# %% [markdown]
# # Ada Boost Regressor

# %%
abr=AdaBoostRegressor(random_state=42)
model_abr=abr.fit(X_train,y_train)

# %%
df_imp_abr=pd.DataFrame({"feature":X_train.columns,"importance":model_abr.feature_importances_})
df_imp_abr.sort_values(by="importance",ascending=False)
# Out:
#    feature  importance
# 5      PC6    0.305973
# 19    PC20    0.304547
# 12    PC13    0.174189
# 0      PC1    0.083758
# 11    PC12    0.066163
# 18    PC19    0.062620
# 10    PC11    0.002604
# 6      PC7    0.000145
# 4      PC5    0.000000
# 3      PC4    0.000000
# 7      PC8    0.000000
# 8      PC9    0.000000
# 9     PC10    0.000000
# 1      PC2    0.000000
# 2      PC3    0.000000
# 13    PC14    0.000000
# 14    PC15    0.000000
# 15    PC16    0.000000
# 16    PC17    0.000000
# 17    PC18    0.000000

# %%
ypred_train=model_abr.predict(X_train)
ypred_test=model_abr.predict(X_test)

# %%
mse_train=mean_squared_error(y_train,ypred_train)
mse_test=mean_squared_error(y_test,ypred_test)
print("Mean squared error for train data:",mse_train)
print("Mean squared error for test data:",mse_test)
# Out:
# Mean squared error for train data: 8295588.311108493
# Mean squared error for test data: 8331066.337120172

# %%
# Example: Cross-validation with 3 folds
scores = cross_val_score(AdaBoostRegressor(random_state=42), X, y, cv=3, scoring='neg_mean_squared_error')
print("Cross-validated RMSE:", -scores)
# Out:
# Cross-validated RMSE: [8348333.13449341 9525967.29580601 8474380.87502543]

# %%
print(np.min(-scores),np.max(-scores),np.mean(-scores))
# Out:
# 8348333.134493412 9525967.295806007 8782893.768441616

# %% [markdown]
# # Gradient Boost Regressor

# %%
gbr=GradientBoostingRegressor(random_state=42)
model_gbr=gbr.fit(X_train,y_train)

# %%
df_imp_gbr=pd.DataFrame({"feature":X_train.columns,"importance":model_gbr.feature_importances_})
df_imp_gbr.sort_values(by="importance",ascending=False)
# Out:
#    feature  importance
# 19    PC20    0.277103
# 12    PC13    0.252325
# 5      PC6    0.180833
# 11    PC12    0.153278
# 18    PC19    0.070810
# 0      PC1    0.061210
# 14    PC15    0.003455
# 10    PC11    0.000580
# 8      PC9    0.000197
# 3      PC4    0.000194
# 1      PC2    0.000014
# 6      PC7    0.000000
# 7      PC8    0.000000
# 9     PC10    0.000000
# 4      PC5    0.000000
# 13    PC14    0.000000
# 15    PC16    0.000000
# 16    PC17    0.000000
# 17    PC18    0.000000
# 2      PC3    0.000000

# %%
ypred_train=model_gbr.predict(X_train)
ypred_test=model_gbr.predict(X_test)

# %%
mse_train=mean_squared_error(y_train,ypred_train)
mse_test=mean_squared_error(y_test,ypred_test)
print("Mean squared error for train data:",mse_train)
print("Mean squared error for test data:",mse_test)
# Out:
# Mean squared error for train data: 6920652.226526251
# Mean squared error for test data: 7054832.8326270105

# %%
# Example: Cross-validation with 3 folds
scores = cross_val_score(GradientBoostingRegressor(random_state=42), X, y, cv=3, scoring='neg_mean_squared_error')
print("Cross-validated RMSE:", -scores)
# Out:
# Cross-validated RMSE: [8038088.71550337 9273306.57472286 8805762.12188278]

# %%
print(np.min(-scores),np.max(-scores),np.mean(-scores))
# Out:
# 8038088.715503374 9273306.574722856 8705719.13736967

# %%
# XGBoost Regressor

# %%
xgbr=XGBRegressor(random_state=42)
model_xgbr=xgbr.fit(X_train,y_train)

# %%
df_imp_xgbr=pd.DataFrame({"feature":X_train.columns,"importance":model_xgbr.feature_importances_})
df_imp_xgbr.sort_values(by="importance",ascending=False)
# Out:
#    feature  importance
# 19    PC20    0.158536
# 12    PC13    0.130220
# 11    PC12    0.116366
# 5      PC6    0.110730
# 0      PC1    0.093404
# 18    PC19    0.081165
# 10    PC11    0.042192
# 3      PC4    0.035167
# 14    PC15    0.034274
# 8      PC9    0.025708
# 13    PC14    0.019135
# 16    PC17    0.018722
# 17    PC18    0.018706
# 15    PC16    0.017741
# 6      PC7    0.017572
# 7      PC8    0.017462
# 9     PC10    0.017031
# 4      PC5    0.016715
# 1      PC2    0.016130
# 2      PC3    0.013024

# %%
ypred_train=model_xgbr.predict(X_train)
ypred_test=model_xgbr.predict(X_test)

# %%
mse_train=mean_squared_error(y_train,ypred_train)
mse_test=mean_squared_error(y_test,ypred_test)
print("Mean squared error for train data:",mse_train)
print("Mean squared error for test data:",mse_test)
# Out:
# Mean squared error for train data: 2961546.649330562
# Mean squared error for test data: 4199890.220706725

# %%
# Example: Cross-validation with 3 folds
scores = cross_val_score(XGBRegressor(random_state=42), X, y, cv=3, scoring='neg_mean_squared_error')
print("Cross-validated RMSE:", -scores)
# Out:
# Cross-validated RMSE: [10244439.23136117  9441074.56212129  9173854.96164762]

# %%
print(np.min(-scores),np.max(-scores),np.mean(-scores))
# Out:
# 9173854.961647622 10244439.231361175 9619789.585043363

# %% [markdown]
# # Stacking Regressor

# %%
base_estimators=[
    ("XGBoostRegressor", XGBRegressor(random_state=42)),
    ("RandomForestRegressor", RandomForestRegressor(random_state=42, n_jobs=-1))
]
sr=StackingRegressor(estimators=base_estimators,final_estimator=DecisionTreeRegressor(random_state=42))
model_sr=sr.fit(X_train,y_train)

# %%
ypred_train=model_sr.predict(X_train)
ypred_test=model_sr.predict(X_test)

# %%
mse_train=mean_squared_error(y_train,ypred_train)
mse_test=mean_squared_error(y_test,ypred_test)
print("Mean squared error for train data:",mse_train)
print("Mean squared error for test data:",mse_test)
# Out:
# Mean squared error for train data: 2283940.8838339224
# Mean squared error for test data: 4609380.803900785

# %%
# Example: Cross-validation with 3 folds
scores = cross_val_score(sr, X, y, cv=3, scoring='neg_mean_squared_error')
print("Cross-validated RMSE:", -scores)
# Out:
# Cross-validated RMSE: [16300067.9140095  16144778.83823779 12693098.55179578]

# %%
print(np.min(-scores),np.max(-scores),np.mean(-scores))
# Out:
# 12693098.551795784 16300067.914009498 15045981.768014356

# %%
base_estimators=[
    ("DecisionTreeRegressor", DecisionTreeRegressor(random_state=42)),
    ("RandomForestRegressor", RandomForestRegressor(random_state=42, n_jobs=-1))
]
sr=StackingRegressor(estimators=base_estimators,final_estimator=XGBRegressor(random_state=42))
model_sr=sr.fit(X_train,y_train)

# %%
ypred_train=model_sr.predict(X_train)
ypred_test=model_sr.predict(X_test)

# %%
mse_train=mean_squared_error(y_train,ypred_train)
mse_test=mean_squared_error(y_test,ypred_test)
print("Mean squared error for train data:",mse_train)
print("Mean squared error for test data:",mse_test)
# Out:
# Mean squared error for train data: 105712.78454069805
# Mean squared error for test data: 2125626.4775746525

# %%
# Example: Cross-validation with 3 folds
scores = cross_val_score(StackingRegressor(estimators=[
    ("DecisionTreeRegressor", DecisionTreeRegressor(random_state=42)),
    ("RandomForestRegressor", RandomForestRegressor(random_state=42, n_jobs=-1))
],final_estimator=XGBRegressor(random_state=42)), X, y, cv=3, scoring='neg_mean_squared_error')
print("Cross-validated RMSE:", -scores)
# Out:
# Cross-validated RMSE: [12761187.6362493  10769341.80824901 13973703.2729621 ]

# %%
print(np.min(-scores),np.max(-scores),np.mean(-scores))
# Out:
# 10769341.808249012 13973703.272962103 12501410.905820139

# %% [markdown]
# # Try PCA with best 16 columns (PCA components and additional categorical columns)

# %%
l=['department', 'promotion_name', 'media_type', 'sales_district', 
'store_type', 'video_store', 'yearly_income', 'member_card', 'occupation', 
'store_cost', 'unit_sales', 'SRP', 'net_weight', 'cost', 'store_sqft', 
'promotion_period']

# %% [markdown]
# * ignore cost(y variable), SRP,store_cost,unit_sales,net_weight,store_sqft,promotion_period

# %% [markdown]
# * add 9 columns ['department', 'promotion_name', 'media_type', 'sales_district',
# 'store_type', 'video_store', 'yearly_income', 'member_card', 'occupation'] to 20 PCA columns.

# %%
df_cat=df1[['department', 'promotion_name', 'media_type', 'sales_district',
            'store_type', 'video_store', 'yearly_income', 'member_card', 'occupation']]

# %%
df_cat
# Out:
#                department      promotion_name             media_type  \
# 0               Household  Super Duper Savers  Cash Register Handout
# 1                   Dairy  Super Duper Savers  Cash Register Handout
# 2      Health and Hygiene  Super Duper Savers  Cash Register Handout
# 3                 Produce  Super Duper Savers  Cash Register Handout
# 4            Canned Foods  Super Duper Savers  Cash Register Handout
# ...                   ...                 ...                    ...
# 70746             Produce      Savings Galore        In-Store Coupon
# 70747             Produce      Savings Galore        In-Store Coupon
# 70748           Household      Savings Galore        In-Store Coupon
# 70749             Produce      Savings Galore        In-Store Coupon
# 70750              Snacks      Savings Galore        In-Store Coupon
#
#       sales_district        store_type  video_store  yearly_income  \
# 0          Bremerton       Supermarket            0    $30K - $50K
# 1          Bremerton       Supermarket            0    $30K - $50K
# 2          Bremerton       Supermarket            0    $30K - $50K
# 3          Bremerton       Supermarket            0    $50K - $70K
# 4          Bremerton       Supermarket            0    $50K - $70K
# ...              ...               ...          ...            ...
# 70746       Victoria  Mid-Size Grocery            0  $110K - $130K
# 70747       Victoria  Mid-Size Grocery            0  $110K - $130K
# 70748       Victoria  Mid-Size Grocery            0   $90K - $110K
# 70749       Victoria  Mid-Size Grocery            0   $90K - $110K
# 70750       Victoria  Mid-Size Grocery            0    $30K - $50K
#
#       member_card      occupation
# 0          Bronze  Skilled Manual
# 1          Bronze  Skilled Manual
# 2          Bronze  Skilled Manual
# 3          Normal  Skilled Manual
# 4          Normal  Skilled Manual
# ...           ...             ...
# 70746      Silver      Management
# 70747      Silver      Management
# 70748      Golden    Professional
# 70749      Golden    Professional
# 70750      Bronze          Manual
#
# [70751 rows x 9 columns]

# %%
le=LabelEncoder()
for col in df_cat.columns:
    df_cat[col] = le.fit_transform(df_cat[col])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_25952\1487531190.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat[col] = le.fit_transform(df_cat[col])
# C:\Users\hp\AppData\Local\Temp\ipykernel_25952\1487531190.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat[col] = le.fit_transform(df_cat[col])
# C:\Users\hp\AppData\Local\Temp\ipykernel_25952\1487531190.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat[col] = le.fit_transform(df_cat[col])
# C:\Users\hp\AppData\Local\Temp\ipykernel_25952\1487531190.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat[col] = le.fit_transform(df_cat[col])
# C:\Users\hp\AppData\Local\Temp\ipykernel_25952\1487531190.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat[col] = le.fit_transform(df_cat[col])
# C:\Users\hp\AppData\Local\Temp\ipykernel_25952\1487531190.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat[col] = le.fit_transform(df_cat[col])
# C:\Users\hp\AppData\Local\Temp\ipykernel_25952\1487531190.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat[col] = le.fit_transform(df_cat[col])
# C:\Users\hp\AppData\Local\Temp\ipykernel_25952\1487531190.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat[col] = le.fit_transform(df_cat[col])
# C:\Users\hp\AppData\Local\Temp\ipykernel_25952\1487531190.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat[col] = le.fit_transform(df_cat[col])

# %%
df_cat
# Out:
#        department  promotion_name  media_type  sales_district  store_type  \
# 0              14              38           1               2           4
# 1               9              38           1               2           4
# 2              13              38           1               2           4
# 3              17              38           1               2           4
# 4               5              38           1               2           4
# ...           ...             ...         ...             ...         ...
# 70746          17              35           5              18           2
# 70747          17              35           5              18           2
# 70748          14              35           5              18           2
# 70749          17              35           5              18           2
# 70750          20              35           5              18           2
#
#        video_store  yearly_income  member_card  occupation
# 0                0              4            0           4
# 1                0              4            0           4
# 2                0              4            0           4
# 3                0              5            2           4
# 4                0              5            2           4
# ...            ...            ...          ...         ...
# 70746            0              1            3           1
# 70747            0              1            3           1
# 70748            0              7            1           3
# 70749            0              7            1           3
# 70750            0              4            0           2
#
# [70751 rows x 9 columns]

# %%
X_pca_cat=pd.concat([df_cat,X_pca],axis=1)

# %%
X_pca_cat
# Out:
#        department  promotion_name  media_type  sales_district  store_type  \
# 0              14              38           1               2           4
# 1               9              38           1               2           4
# 2              13              38           1               2           4
# 3              17              38           1               2           4
# 4               5              38           1               2           4
# ...           ...             ...         ...             ...         ...
# 70746          17              35           5              18           2
# 70747          17              35           5              18           2
# 70748          14              35           5              18           2
# 70749          17              35           5              18           2
# 70750          20              35           5              18           2
#
#        video_store  yearly_income  member_card  occupation       PC1  ...  \
# 0                0              4            0           4  4.514427  ...
# 1                0              4            0           4  4.407766  ...
# 2                0              4            0           4  4.373638  ...
# 3                0              5            2           4  4.524975  ...
# 4                0              5            2           4  4.223732  ...
# ...            ...            ...          ...         ...       ...  ...
# 70746            0              1            3           1  1.025363  ...
# 70747            0              1            3           1  0.735296  ...
# 70748            0              7            1           3  0.709828  ...
# 70749            0              7            1           3  0.789311  ...
# 70750            0              4            0           2  0.956258  ...
#
#            PC11      PC12      PC13      PC14      PC15      PC16      PC17  \
# 0     -1.485732 -0.428173 -0.173639 -0.973417 -0.942388 -0.362827  0.045072
# 1     -1.697152 -0.464314 -0.159286  0.526051 -0.987803 -0.376559 -0.010194
# 2     -1.298399 -0.492705 -0.221501 -0.424091 -0.750266 -0.068166  0.037416
# 3      0.703133 -0.592110 -0.332274 -0.830183  0.524281 -0.727250 -0.171523
# 4     -0.957563 -0.549126 -0.126123 -0.917360 -0.006334 -0.116851 -0.235099
# ...         ...       ...       ...       ...       ...       ...       ...
# 70746  0.207094  2.223028  1.262995 -0.740191  1.249848  0.217350 -0.084863
# 70747 -1.868233  2.165762  1.433547 -0.185573  0.816688 -0.611329 -0.427707
# 70748  0.350121  2.224400  1.348922  0.231415 -0.307479 -0.113464  0.062389
# 70749  0.796232  2.170244  1.256801  0.563298 -0.072192 -0.086792 -0.078855
# 70750  2.003854  1.932662  1.108567 -0.070629  1.390526 -0.131988 -0.249311
#
#            PC18      PC19      PC20
# 0      0.014808 -0.008978 -0.000206
# 1      0.140271 -0.008533 -0.000208
# 2      0.132735 -0.008790 -0.000213
# 3     -0.160199 -0.009989 -0.000208
# 4      0.027235 -0.008443 -0.000196
# ...         ...       ...       ...
# 70746 -0.004281 -0.013234 -0.000404
# 70747 -0.009264 -0.011574 -0.000396
# 70748  0.155655 -0.011816 -0.000404
# 70749 -0.007849 -0.011894 -0.000409
# 70750  0.143150 -0.012710 -0.000405
#
# [70751 rows x 29 columns]

# %%
y=df_num["cost"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pca_cat, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Linear Regression

# %%
model_lr=LinearRegression().fit(X_train,y_train)

# %%
ypred_train=model_lr.predict(X_train)
ypred_test=model_lr.predict(X_test)

# %%
mse_train=mean_squared_error(y_train,ypred_train)
mse_test=mean_squared_error(y_test,ypred_test)
print("Mean squared error for train data:",mse_train)
print("Mean squared error for test data:",mse_test)
# Out:
# Mean squared error for train data: 8509614.52289576
# Mean squared error for test data: 8517068.049463183

# %%
from sklearn.model_selection import cross_val_score
model_lr=LinearRegression()
# Example: Cross-validation with 3 folds
scores = cross_val_score(model_lr, X_pca_cat, y, cv=3, scoring='neg_mean_squared_error')
print("Cross-validated RMSE:", -scores)
# Out:
# Cross-validated RMSE: [8723641.25245674 9586837.11863598 8763684.31084193]

# %%
print(np.min(-scores),np.max(-scores),np.mean(-scores))
# Out:
# 8723641.25245674 9586837.118635984 9024720.893978218

# %% [markdown]
# # Decision Tree Regressor

# %%
dtr=DecisionTreeRegressor(random_state=42)
model_dtr=dtr.fit(X_train,y_train)

# %%
df_imp_dt=pd.DataFrame({"feature":X_train.columns,"importance":model_dtr.feature_importances_})
df_imp_dt.sort_values(by="importance",ascending=False)
# Out:
#            feature    importance
# 1   promotion_name  3.507065e-01
# 2       media_type  1.781645e-01
# 28            PC20  1.317007e-01
# 3   sales_district  8.923360e-02
# 4       store_type  7.944162e-02
# 21            PC13  6.276872e-02
# 9              PC1  3.447328e-02
# 14             PC6  2.524294e-02
# 20            PC12  2.456480e-02
# 27            PC19  1.617626e-02
# 5      video_store  7.063072e-03
# 12             PC4  2.576200e-04
# 10             PC2  5.087349e-05
# 16             PC8  4.459480e-05
# 19            PC11  2.684244e-05
# 22            PC14  2.586010e-05
# 6    yearly_income  1.550188e-05
# 24            PC16  1.534950e-05
# 13             PC5  5.906555e-06
# 18            PC10  5.623510e-06
# 15             PC7  5.319387e-06
# 23            PC15  4.731109e-06
# 7      member_card  3.645113e-06
# 17             PC9  2.143445e-06
# 8       occupation  9.732414e-10
# 25            PC17  0.000000e+00
# 26            PC18  0.000000e+00
# 11             PC3  0.000000e+00
# 0       department  0.000000e+00

# %%
ypred_train=model_dtr.predict(X_train)
ypred_test=model_dtr.predict(X_test)

# %%
mse_train=mean_squared_error(y_train,ypred_train)
mse_test=mean_squared_error(y_test,ypred_test)
print("Mean squared error for train data:",mse_train)
print("Mean squared error for test data:",mse_test)
# Out:
# Mean squared error for train data: 0.0
# Mean squared error for test data: 61562.024521235246

# %%
# Example: Cross-validation with 3 folds
scores = cross_val_score(DecisionTreeRegressor(random_state=42), X_pca_cat, y, cv=3, scoring='neg_mean_squared_error')
print("Cross-validated MSE:", -scores)
# Out:
# Cross-validated MSE: [14097829.23316655 16415181.89272388 15366373.84955264]

# %%
print(np.min(-scores),np.max(-scores),np.mean(-scores))
# Out:
# 14097829.233166553 16415181.89272388 15293128.325147694

# %% [markdown]
# # Random Forest Regressor

# %%
rfr=RandomForestRegressor(random_state=42,n_jobs=-1)
model_rfr=rfr.fit(X_train,y_train)

# %%
df_imp_rfr=pd.DataFrame({"feature":X_train.columns,"importance":model_rfr.feature_importances_})
df_imp_rfr.sort_values(by="importance",ascending=False)
# Out:
#            feature  importance
# 1   promotion_name    0.362317
# 2       media_type    0.199884
# 28            PC20    0.091333
# 21            PC13    0.074402
# 3   sales_district    0.066219
# 4       store_type    0.057484
# 14             PC6    0.049449
# 20            PC12    0.037241
# 27            PC19    0.029041
# 9              PC1    0.022849
# 5      video_store    0.005950
# 19            PC11    0.001475
# 12             PC4    0.000599
# 17             PC9    0.000264
# 23            PC15    0.000248
# 10             PC2    0.000172
# 25            PC17    0.000141
# 18            PC10    0.000131
# 13             PC5    0.000127
# 15             PC7    0.000124
# 6    yearly_income    0.000078
# 24            PC16    0.000076
# 22            PC14    0.000076
# 16             PC8    0.000075
# 26            PC18    0.000061
# 11             PC3    0.000058
# 8       occupation    0.000055
# 0       department    0.000047
# 7      member_card    0.000025

# %%
ypred_train=model_rfr.predict(X_train)
ypred_test=model_rfr.predict(X_test)

# %%
mse_train=mean_squared_error(y_train,ypred_train)
mse_test=mean_squared_error(y_test,ypred_test)
print("Mean squared error for train data:",mse_train)
print("Mean squared error for test data:",mse_test)
# Out:
# Mean squared error for train data: 3323.84784044523
# Mean squared error for test data: 15450.722017595932

# %%
# Example: Cross-validation with 3 folds
scores = cross_val_score(RandomForestRegressor(random_state=42,n_jobs=-1), X_pca_cat, y, cv=3, scoring='neg_mean_squared_error')
print("Cross-validated RMSE:", -scores)
# Out:
# Cross-validated RMSE: [ 9847770.04112853 11861097.17149523 10561060.2508035 ]

# %%
print(np.min(-scores),np.max(-scores),np.mean(-scores))
# Out:
# 9847770.04112853 11861097.17149523 10756642.487809086

# %% [markdown]
# # AdaBoost Regressor

# %%
abr=AdaBoostRegressor(random_state=42)
model_abr=abr.fit(X_train,y_train)

# %%
df_imp_abr=pd.DataFrame({"feature":X_train.columns,"importance":model_abr.feature_importances_})
df_imp_abr.sort_values(by="importance",ascending=False)
# Out:
#            feature  importance
# 1   promotion_name    0.312513
# 2       media_type    0.188346
# 14             PC6    0.090879
# 3   sales_district    0.090301
# 28            PC20    0.090020
# 9              PC1    0.073239
# 21            PC13    0.055307
# 27            PC19    0.043662
# 4       store_type    0.036567
# 20            PC12    0.019167
# 5      video_store    0.000000
# 18            PC10    0.000000
# 26            PC18    0.000000
# 25            PC17    0.000000
# 24            PC16    0.000000
# 23            PC15    0.000000
# 22            PC14    0.000000
# 19            PC11    0.000000
# 17             PC9    0.000000
# 6    yearly_income    0.000000
# 16             PC8    0.000000
# 15             PC7    0.000000
# 13             PC5    0.000000
# 12             PC4    0.000000
# 11             PC3    0.000000
# 10             PC2    0.000000
# 8       occupation    0.000000
# 7      member_card    0.000000
# 0       department    0.000000

# %%
ypred_train=model_abr.predict(X_train)
ypred_test=model_abr.predict(X_test)

# %%
mse_train=mean_squared_error(y_train,ypred_train)
mse_test=mean_squared_error(y_test,ypred_test)
print("Mean squared error for train data:",mse_train)
print("Mean squared error for test data:",mse_test)
# Out:
# Mean squared error for train data: 8205610.765504865
# Mean squared error for test data: 8233081.024915331

# %%
# Example: Cross-validation with 3 folds
scores = cross_val_score(AdaBoostRegressor(random_state=42), X_pca_cat, y, cv=3, scoring='neg_mean_squared_error')
print("Cross-validated RMSE:", -scores)
# Out:
# Cross-validated RMSE: [8819065.36465492 9931981.11488148 8745802.83489225]

# %%
print(np.min(-scores),np.max(-scores),np.mean(-scores))
# Out:
# 8745802.834892245 9931981.11488148 9165616.43814288

# %% [markdown]
# # Gradient Boost Regressor

# %%
gbr=GradientBoostingRegressor(random_state=42)
model_gbr=gbr.fit(X_train,y_train)

# %%
df_imp_gbr=pd.DataFrame({"feature":X_train.columns,"importance":model_gbr.feature_importances_})
df_imp_gbr.sort_values(by="importance",ascending=False)
# Out:
#            feature  importance
# 1   promotion_name    0.303969
# 2       media_type    0.188461
# 21            PC13    0.103628
# 28            PC20    0.093743
# 27            PC19    0.068898
# 14             PC6    0.054935
# 4       store_type    0.051602
# 20            PC12    0.046985
# 3   sales_district    0.042909
# 9              PC1    0.033788
# 5      video_store    0.011064
# 23            PC15    0.000017
# 6    yearly_income    0.000000
# 19            PC11    0.000000
# 26            PC18    0.000000
# 25            PC17    0.000000
# 24            PC16    0.000000
# 22            PC14    0.000000
# 17             PC9    0.000000
# 18            PC10    0.000000
# 7      member_card    0.000000
# 16             PC8    0.000000
# 15             PC7    0.000000
# 13             PC5    0.000000
# 12             PC4    0.000000
# 11             PC3    0.000000
# 10             PC2    0.000000
# 8       occupation    0.000000
# 0       department    0.000000

# %%
ypred_train=model_gbr.predict(X_train)
ypred_test=model_gbr.predict(X_test)

# %%
mse_train=mean_squared_error(y_train,ypred_train)
mse_test=mean_squared_error(y_test,ypred_test)
print("Mean squared error for train data:",mse_train)
print("Mean squared error for test data:",mse_test)
# Out:
# Mean squared error for train data: 4363206.553473026
# Mean squared error for test data: 4425258.802412323

# %%
# Example: Cross-validation with 3 folds
scores = cross_val_score(GradientBoostingRegressor(random_state=42), X_pca_cat, y, cv=3, scoring='neg_mean_squared_error')
print("Cross-validated RMSE:", -scores)
# Out:
# Cross-validated RMSE: [8964169.95554146 9346512.30784925 9113079.88811732]

# %%
print(np.min(-scores),np.max(-scores),np.mean(-scores))
# Out:
# 8964169.955541456 9346512.307849254 9141254.050502678

# %% [markdown]
# # XGBoost Regressor

# %%
xgbr=XGBRegressor(random_state=42)
model_xgbr=xgbr.fit(X_train,y_train)

# %%
df_imp_xgbr=pd.DataFrame({"feature":X_train.columns,"importance":model_xgbr.feature_importances_})
df_imp_xgbr.sort_values(by="importance",ascending=False)
# Out:
#            feature  importance
# 4       store_type    0.165125
# 5      video_store    0.159436
# 1   promotion_name    0.123891
# 2       media_type    0.109866
# 3   sales_district    0.102201
# 28            PC20    0.073417
# 9              PC1    0.070107
# 21            PC13    0.059201
# 27            PC19    0.050922
# 20            PC12    0.038369
# 14             PC6    0.032251
# 7      member_card    0.002800
# 23            PC15    0.001833
# 19            PC11    0.001820
# 12             PC4    0.001274
# 17             PC9    0.001171
# 10             PC2    0.001127
# 0       department    0.000588
# 8       occupation    0.000572
# 25            PC17    0.000557
# 13             PC5    0.000517
# 26            PC18    0.000442
# 22            PC14    0.000434
# 11             PC3    0.000414
# 24            PC16    0.000411
# 16             PC8    0.000367
# 18            PC10    0.000350
# 6    yearly_income    0.000280
# 15             PC7    0.000256

# %%
ypred_train=model_xgbr.predict(X_train)
ypred_test=model_xgbr.predict(X_test)

# %%
mse_train=mean_squared_error(y_train,ypred_train)
mse_test=mean_squared_error(y_test,ypred_test)
print("Mean squared error for train data:",mse_train)
print("Mean squared error for test data:",mse_test)
# Out:
# Mean squared error for train data: 74203.94752592011
# Mean squared error for test data: 107664.71672166094

# %%
# Example: Cross-validation with 3 folds
scores = cross_val_score(XGBRegressor(random_state=42), X_pca_cat, y, cv=3, scoring='neg_mean_squared_error')
print("Cross-validated RMSE:", -scores)
# Out:
# Cross-validated RMSE: [9740151.39785446 9771588.93474275 9586243.53502975]

# %%
print(np.min(-scores),np.max(-scores),np.mean(-scores))
# Out:
# 9586243.535029747 9771588.934742752 9699327.955875652

# %% [markdown]
# # Stacking Regressor

# %%
base_estimators=[
    ("XGBoostRegressor", XGBRegressor(random_state=42)),
    ("RandomForestRegressor", RandomForestRegressor(random_state=42, n_jobs=-1))
]
sr=StackingRegressor(estimators=base_estimators,final_estimator=DecisionTreeRegressor(random_state=42))
model_sr=sr.fit(X_train,y_train)

# %%
ypred_train=model_sr.predict(X_train)
ypred_test=model_sr.predict(X_test)

# %%
mse_train=mean_squared_error(y_train,ypred_train)
mse_test=mean_squared_error(y_test,ypred_test)
print("Mean squared error for train data:",mse_train)
print("Mean squared error for test data:",mse_test)
# Out:
# Mean squared error for train data: 9214.986961130742
# Mean squared error for test data: 24960.635361458553

# %%
# Example: Cross-validation with 3 folds
scores = cross_val_score(sr, X_pca_cat, y, cv=3, scoring='neg_mean_squared_error')
print("Cross-validated RMSE:", -scores)
# Out:
# Cross-validated RMSE: [14449016.78235244 14984929.97807836 15212527.92346182]

# %%
print(np.min(-scores),np.max(-scores),np.mean(-scores))
# Out:
# 14449016.782352442 15212527.923461815 14882158.227964206

# %%
base_estimators=[
    ("DecisionTreeRegressor", DecisionTreeRegressor(random_state=42)),
    ("RandomForestRegressor", RandomForestRegressor(random_state=42, n_jobs=-1))
]
sr=StackingRegressor(estimators=base_estimators,final_estimator=XGBRegressor(random_state=42))
model_sr=sr.fit(X_train,y_train)

# %%
ypred_train=model_sr.predict(X_train)
ypred_test=model_sr.predict(X_test)

# %%
mse_train=mean_squared_error(y_train,ypred_train)
mse_test=mean_squared_error(y_test,ypred_test)
print("Mean squared error for train data:",mse_train)
print("Mean squared error for test data:",mse_test)
# Out:
# Mean squared error for train data: 1284.5074922993663
# Mean squared error for test data: 7921.467827924814

# %%
# Example: Cross-validation with 3 folds
scores = cross_val_score(StackingRegressor(estimators=[
    ("DecisionTreeRegressor", DecisionTreeRegressor(random_state=42)),
    ("RandomForestRegressor", RandomForestRegressor(random_state=42, n_jobs=-1))
],final_estimator=XGBRegressor(random_state=42)), X_pca_cat, y, cv=3, scoring='neg_mean_squared_error')
print("Cross-validated RMSE:", -scores)
# Out:
# Cross-validated RMSE: [11512831.14157326 14195786.30278922 13670947.68130908]

# %%
print(np.min(-scores),np.max(-scores),np.mean(-scores))
# Out:
# 11512831.141573256 14195786.302789224 13126521.708557187
